# %%
import numpy as np 
from scipy.integrate import odeint 
import matplotlib.pyplot as plt 

x = [0.00000002, 0.00000003, 0.00000004, 0.00000006, 0.00000008, 0.0000001, 0.0000003, 0.0000005, 0.0000008]
e = [0, 0, 0.0103, 0.1107, 0.1181, 0.1234, 0.1327, 0.134, 0.1348]
o = [0.0187, 0.6898, 0.7629, 0.7924, 0.8072, 0.8213, 0.8469, 0.8558, 0.8645]
c = [0.9813, 0.3102, 0.2268, 0.0968, 0.0747, 0.0552, 0.0204, 0.0102, 0.000756]

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x, e, label='erlotinib%')
ax.plot(x, o, label='osimertinib%')
ax.plot(x, c, label='combination%')
ax.legend()

ax.set_xscale('log')
ax.set_xlabel('kC')
ax.set_ylabel('Region%')
ax.set_title('kC')

plt.show()
